# %%
import os
import sys
import shutil
import glob
from PIL import Image , ImageOps

original=glob.glob('C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\02_bmp\\*')
n=0
print('Start LRseg')
for i in original:
    n=n+1
    strs=i.split('_')
    if strs[5] == 'L':
        shutil.copy(i,'C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\invL')
    else:
        shutil.copy(i,'C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\invR')
    out = str(n) + "/1000\n"
    print(out)
n=0
print('Start invert L')

picl=glob.glob('C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\invL\\*')
for i in picl:
    n=n+1
    base=os.path.basename(i)
    new_file = 'C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\invL2\\' + base 
    im=Image.open(i)
    imflip=ImageOps.flip(im)
    imflip.save(new_file)
    out = str(n)
    print(out)

n=0
print('integrateLR')
picr=glob.glob('C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\invR\\*')
picl_inv=glob.glob('C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\invL2\\*')
for i in picr:
    n=n+1
    shutil.copy(i,'C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\ALLINVED')
    out=str(n)+ "/1000\n"
    print(out)
for i in picl_inv:
    n=n+1
    shutil.copy(i,'C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\ALLINVED')
    out=str(n)+ "/1000\n"
    print (out)

data=glob.glob('C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\ALLINVED\\*')
count=0
for i in data:
    im=Image.open(i)
    nameseed=os.path.basename(i)
    for n in range(217):
        count=count+1
        left=16*n
        upper=100
        right=16*n+128
        lower=228
        im_crop=im.crop((left,upper,right,lower))

        numbering="{0:03d}".format(n)
        savepath="C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\padd\\"+ numbering +'_'+ nameseed
        im_crop.save(savepath)
        out=str(count)+"/434,000"
        print(out)

n=0
lists = glob.glob("C:\\Users\\XXX\\Desktop\\201910101303_d3qa\\99_temp\\padd\\*.bmp")
for i in lists:
    n=n+1
    base = os.path.basename(i)
    strs=base.split('_')
    new_str=strs[1]+'_'+strs[2]+'_'+strs[3]+'_'+strs[4]+'_'+strs[5]+'_'+strs[6]+'_'+strs[7]+strs[0]+'_'+'.bmp'
    os.rename(i,new_str)
    out = str(n) + "/434565"
    print(out)
